# %%
import pandas as pd
import matplotlib as plt

df=pd.read_csv("/Users/lukeofthehill/Downloads/audio_analysis_results.csv")
df.fillna(0,inplace=True)

# %%
df.bpm.hist()
df['bpm'].describe()
# Out:
# count    8491.000000
# mean      124.300223
# std        27.500477
# min         0.000000
# 25%       105.470000
# 50%       123.050000
# 75%       143.550000
# max       258.400000
# Name: bpm, dtype: float64

# %%
df.rms.hist()
df['rms'].describe()
# Out:
# count    8491.000000
# mean        0.187096
# std         0.069177
# min         0.007000
# 25%         0.136500
# 50%         0.190900
# 75%         0.236100
# max         0.518600
# Name: rms, dtype: float64

# %%
import numpy as np 
df = df[np.isfinite(df.lufs)]
df.lufs.hist()
df['lufs'].describe()
# Out:
# count    8491.000000
# mean      -14.693954
# std         3.480544
# min       -46.840000
# 25%       -16.470000
# 50%       -13.940000
# 75%       -12.280000
# max        -4.120000
# Name: lufs, dtype: float64
